# %% [markdown]
# # 2. Biocellion Sensitivity Analysis - Run
# This notebook defines functions to run simulations for the Biocellion ABM models by the CMMC that can be found in github.com/TheCMMC. For more information on the CMMC, visit www.thecmmc.org.

# %%
import os
import re

import pandas as pd
import xml.etree.ElementTree as ET

from pathlib import Path
from datetime import datetime
from itertools import chain

# %% [markdown]
# ## User settings

# %%
# Set this data folder to the place where you cloned the repository https://github.com/TheCMMC/biocellion-data
MODEL_FOLDER = Path("/home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers")
TOOLS_FOLDER = Path("/home/jaroknor/NLeSC/InSilicoMeat/Biocellion/biocellion-tools")

# %% [markdown]
# ## Run biocellion simulations
# Now that we have sampled the parameters, we can run all simulations for these parameter sets. We need to fill in the paramater values in the correct place in the biocellion files and compile the model. Then run the model and store the results. The output of each run will get a unique time stamp and a parameter file that contains the parameters for that run.

# %%
class Model:
    def __init__(self, param_vector, model_folder, output_base_folder, problem, param_info, num_steps=None):
        self.param_vector = param_vector
        self.model_folder = model_folder
        self.output_base_folder = output_base_folder
        self.problem = problem
        self.param_info = param_info
        self.num_steps = num_steps
        
        self.init_time = None
        self.timestamp = None
        self.xml = None
        self.xml_path = None
        self.output_location = None
        
        self._set_timestamp()
        
        
    def _set_timestamp(self):
        self.init_time = datetime.now()
        self.timestamp = self.init_time.strftime("%Y%m%d-%H%M%S")


    def _prepare_xml(self):
        """Read original xml file and write to timestamped new file"""

        base_xml_path = self.model_folder / "run_model.xml"
        self.xml = ET.parse(base_xml_path)
        self.xml_path = base_xml_path.with_stem(f"run_model_{self.timestamp}")
        self.xml.write(self.xml_path)

    def _prepare_output_location(self):
        """Creates new timestamped folder and renames output paths in xml file"""

        self.output_location = self.output_base_folder / f"output_{self.timestamp}"
        os.mkdir(self.output_location)

        #  rename the output paths 
        root = self.xml.getroot()
        for element in chain(root.iter("output"), root.iter("stdout")):
            element.set("path", str(self.output_location))
        self.xml.write(self.xml_path)
        
    def _write_simulation_info(self):
        param_sample_df = pd.DataFrame([self.param_vector], columns=self.problem["names"])
        param_sample_df.to_csv(self.output_location / f"parameters_{self.timestamp}.csv")

    def _set_num_steps(self):
        """Creates new timestamped folder and renames output paths in xml file"""

        root = self.xml.getroot()
        for element in root.iter("time_step"):
            element.set("end", str(self.num_steps))
        self.xml.write(self.xml_path)        
        

    def _enter_parameter(self, index, value):
        info = self.param_info.loc[index]
        parameter_loc = self.model_folder / info["file"]
        param_type, param_name = info["type"], info["name"]
        string = f"const {param_type} {param_name} = .+ ;" 
        pattern = re.compile(string)
        new_string = f"const {param_type} {param_name} = {value} ;"
        
        with open(parameter_loc, "r") as file:
            content = file.read()
            assert re.search(pattern, content)
            content = re.sub(pattern, new_string, content)
            
        with open(parameter_loc, "w") as file:
            file.write(content) 
        
        
    def prepare(self):
        """Enters the parameter values and output locations in the right file and place, then compiles the model."""

        print(f"Preparing model at {self.init_time}")
        self._prepare_xml()
        self._prepare_output_location()
        self._write_simulation_info()
        if self.num_steps:
            self._set_num_steps()
        for i, value in enumerate(self.param_vector):
            self._enter_parameter(i, value)
        print(f"Output will be collected in: \n {self.output_location}")


    def build(self):
        """Builds the model using make, after cleaning up the previous build"""
        print("Building the model...")
        cwd = os.getcwd()
        os.chdir(self.model_folder)
        
        os.system("make clean")
        os.system("make -s")

        os.chdir(cwd)

        
    def run(self):
        print(f"Starting simulation with {self.xml_path.stem}")
        cwd = os.getcwd()
        os.chdir(self.model_folder)
        # !biocellion {self.xml_path}
        os.chdir(cwd)
        os.rename(self.xml_path, self.output_location / self.xml_path.name)

# %%
output_base_folder = MODEL_FOLDER / "output"
model = Model(param_sample[0], MODEL_FOLDER, output_base_folder, problem, param_info, num_steps=101)
model.prepare()
model.build()
model.run()
# Out:
# Preparing model at 2021-06-21 17:33:00.371283
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output/output_20210621-173300
# Building the model...
# Starting simulation with run_model_20210621-173300
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.

# %%
def run_batch(param_vectors, problem, param_info, model_folder, num_steps=101):
    # Create the parameter sample file to be able to rerun the same batch
    timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
    batch_output_folder = model_folder / f"output_SA_{timestamp}"
    os.mkdir(batch_output_folder)
    param_sample_df = pd.DataFrame(param_vectors, columns=problem["names"])
    param_sample_df.to_csv(batch_output_folder / f"parameter_sample_{timestamp}.csv")
    param_info.to_csv(batch_output_folder / f"parameter_info_{timestamp}.csv")
    
    for i, param_vector in enumerate(param_vectors):
        print(f"Starting run for parameter set {i}")
        model = Model(param_vector, model_folder, batch_output_folder, problem, param_info, num_steps=num_steps)
        model.prepare()
        model.build()
        model.run()
        print("---------------- \n")

# %%
run_batch(param_sample, problem, param_info, MODEL_FOLDER, num_steps=120000)
# Out:
# Starting run for parameter set 0
# Preparing model at 2021-06-04 17:59:35.226399
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210604-175935
# Building the model...
# Starting simulation with run_model_20210604-175935
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.0002 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 1
# Preparing model at 2021-06-04 18:13:23.076155
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210604-181323
# Building the model...
# Starting simulation with run_model_20210604-181323
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.00023 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 2
# Preparing model at 2021-06-04 18:25:04.626915
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210604-182504
# Building the model...
# Starting simulation with run_model_20210604-182504
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000231 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 3
# Preparing model at 2021-06-04 18:36:41.604051
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210604-183641
# Building the model...
# Starting simulation with run_model_20210604-183641
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000578 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 4
# Preparing model at 2021-06-04 19:19:20.669074
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210604-191920
# Building the model...
# Starting simulation with run_model_20210604-191920
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.012444 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 5
# Preparing model at 2021-06-05 15:03:08.100718
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210605-150308
# Building the model...
# Starting simulation with run_model_20210605-150308
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000569 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 6
# Preparing model at 2021-06-06 04:33:18.888528
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210606-043318
# Building the model...
# Starting simulation with run_model_20210606-043318
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.00477 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 7
# Preparing model at 2021-06-06 14:46:44.749310
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210606-144644
# Building the model...
# Starting simulation with run_model_20210606-144644
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.005355 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 8
# Preparing model at 2021-06-06 21:40:04.350168
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210606-214004
# Building the model...
# Starting simulation with run_model_20210606-214004
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000259 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 9
# Preparing model at 2021-06-06 21:54:47.483392
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210606-215447
# Building the model...
# Starting simulation with run_model_20210606-215447
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.001207 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 10
# Preparing model at 2021-06-07 03:45:15.429289
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-034515
# Building the model...
# Starting simulation with run_model_20210607-034515
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.003733 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 11
# Preparing model at 2021-06-07 12:28:04.362802
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-122804
# Building the model...
# Starting simulation with run_model_20210607-122804
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000274 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 12
# Preparing model at 2021-06-07 12:43:51.406189
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-124351
# Building the model...
# Starting simulation with run_model_20210607-124351
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000253 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 13
# Preparing model at 2021-06-07 13:00:49.754825
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-130049
# Building the model...
# Starting simulation with run_model_20210607-130049
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000524 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 14
# Preparing model at 2021-06-07 13:45:18.006102
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-134518
# Building the model...
# Starting simulation with run_model_20210607-134518
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000255 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 15
# Preparing model at 2021-06-07 13:59:26.860220
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-135926
# Building the model...
# Starting simulation with run_model_20210607-135926
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000361 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 16
# Preparing model at 2021-06-07 14:19:47.242064
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-141947
# Building the model...
# Starting simulation with run_model_20210607-141947
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000232 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 17
# Preparing model at 2021-06-07 14:34:29.377119
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-143429
# Building the model...
# Starting simulation with run_model_20210607-143429
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.001129 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 18
# Preparing model at 2021-06-07 15:21:19.845072
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-152119
# Building the model...
# Starting simulation with run_model_20210607-152119
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.0007 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 19
# Preparing model at 2021-06-07 16:24:22.600794
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-162422
# Building the model...
# Starting simulation with run_model_20210607-162422
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000229 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 20
# Preparing model at 2021-06-07 16:38:47.235787
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210607-163847
# Building the model...
# Starting simulation with run_model_20210607-163847
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.005594 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 21
# Preparing model at 2021-06-08 04:05:23.174582
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210608-040523
# Building the model...
# Starting simulation with run_model_20210608-040523
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.011238 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 22
# Preparing model at 2021-06-08 18:54:18.287240
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210608-185418
# Building the model...
# Starting simulation with run_model_20210608-185418
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.001205 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 23
# Preparing model at 2021-06-08 23:02:12.747850
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210608-230212
# Building the model...
# Starting simulation with run_model_20210608-230212
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000753 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 24
# Preparing model at 2021-06-09 01:01:48.625414
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-010148
# Building the model...
# Starting simulation with run_model_20210609-010148
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.001038 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 25
# Preparing model at 2021-06-09 02:46:12.041049
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-024612
# Building the model...
# Starting simulation with run_model_20210609-024612
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000928 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 26
# Preparing model at 2021-06-09 04:04:29.687431
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-040429
# Building the model...
# Starting simulation with run_model_20210609-040429
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000233 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 27
# Preparing model at 2021-06-09 04:18:03.719503
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-041803
# Building the model...
# Starting simulation with run_model_20210609-041803
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000496 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 28
# Preparing model at 2021-06-09 05:01:18.623184
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-050118
# Building the model...
# Starting simulation with run_model_20210609-050118
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000656 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 29
# Preparing model at 2021-06-09 07:56:37.025266
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-075637
# Building the model...
# Starting simulation with run_model_20210609-075637
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000827 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 30
# Preparing model at 2021-06-09 09:14:16.898391
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-091416
# Building the model...
# Starting simulation with run_model_20210609-091416
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000231 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 31
# Preparing model at 2021-06-09 09:25:55.853048
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-092555
# Building the model...
# Starting simulation with run_model_20210609-092555
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.0002 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 32
# Preparing model at 2021-06-09 09:40:01.887949
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-094001
# Building the model...
# Starting simulation with run_model_20210609-094001
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000222 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 33
# Preparing model at 2021-06-09 09:51:22.509227
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-095122
# Building the model...
# Starting simulation with run_model_20210609-095122
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000237 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 34
# Preparing model at 2021-06-09 10:02:58.454654
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-100258
# Building the model...
# Starting simulation with run_model_20210609-100258
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.0002 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 35
# Preparing model at 2021-06-09 10:19:14.162589
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-101914
# Building the model...
# Starting simulation with run_model_20210609-101914
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.001368 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 36
# Preparing model at 2021-06-09 12:20:49.692929
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-122049
# Building the model...
# Starting simulation with run_model_20210609-122049
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.000561 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 37
# Preparing model at 2021-06-09 14:28:18.728102
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210609-142818
# Building the model...
# Starting simulation with run_model_20210609-142818
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.004127 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 38
# Preparing model at 2021-06-10 06:43:11.941311
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210610-064311
# Building the model...
# Starting simulation with run_model_20210610-064311
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
# termination took 0.052921 seconds.
# Simulation finished.
# ----------------
#
# Starting run for parameter set 39
# Preparing model at 2021-06-11 10:07:19.934912
# Output will be collected in:
#  /home/jaroknor/NLeSC/InSilicoMeat/Biocellion/Biocellion-3.1/biocellion-3.1/biocellion-user/ABM-microcarriers/output_20210604-175935/output_20210611-100719
# Building the model...
# Starting simulation with run_model_20210611-100719
# WARNING, this binary does not support distributed memory parallelism, and "num_node_groups" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_nodes_per_group" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "num_sockets_per_node" (child element of "system") will be ignored.
# WARNING, this binary does not support distributed memory parallelism, and "load_balance" (attribute of "interval") will be ignored.
# Reading Velocity_220rpm.txt...  read 291016 points.
